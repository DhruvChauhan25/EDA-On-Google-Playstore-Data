# %%
import pandas as pd
# Out:
# C:\Users\niced\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.0' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\niced\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:62: UserWarning: Pandas requires version '1.3.4' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
df=pd.read_csv("Cleaned_google_playstore_data.csv")

# %%
df.head(1)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
#
#    Reviews     Size  Installs  Type  Price Content Rating        Genres  \
# 0      159  19000.0     10000  Free    0.0       Everyone  Art & Design
#
#   Last Updated Current Ver Android Ver  Day  Month  Year
# 0   2018-01-07       1.0.0      4.0.3     7      1  2018

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
# %matplotlib inline

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10835                               Sya9a Maroc - FR               FAMILY
# 10836               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                         Parkinson Exercices FR              MEDICAL
# 10838                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews     Size  Installs  Type  Price Content Rating  \
# 10835     4.5       38  53000.0      5000  Free    0.0       Everyone
# 10836     5.0        4   3600.0       100  Free    0.0       Everyone
# 10837     NaN        3   9500.0      1000  Free    0.0       Everyone
# 10838     4.5      114      NaN      1000  Free    0.0     Mature 17+
# 10839     4.5   398307  19000.0  10000000  Free    0.0       Everyone
#
#                   Genres Last Updated         Current Ver Android Ver  Day  \
# ...

# %%
df.sample(n=5)
# Out:
#                                                 App     Category  Rating  \
# 8572             DM Buddy » Learn Digital Marketing       FAMILY     5.0
# 4364                                          GTS-M        TOOLS     4.2
# 2500                              Blue CareOnDemand      MEDICAL     4.4
# 2575  💘 WhatsLov: Smileys of love, stickers and GIF       SOCIAL     4.6
# 6900               Black & White Camera - Lovely BW  PHOTOGRAPHY     4.2
#
#       Reviews     Size  Installs  Type  Price Content Rating       Genres  \
# 8572        3   1700.0       500  Free    0.0       Everyone    Education
# 4364       38    251.0      5000  Free    0.0       Everyone        Tools
# 2500      163  40000.0     10000  Free    0.0       Everyone      Medical
# 2575    22098  18000.0   1000000  Free    0.0       Everyone       Social
# 6900      329   4800.0    100000  Free    0.0       Everyone  Photography
#
#      Last Updated    Current Ver Android Ver  Day  Month  Year
# ...

# %%
df.shape
# Out:
# (10840, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10840 entries, 0 to 10839
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     9476 non-null   object
#  13  Day             10840 non-null  int64
#  14  Month           10840 non-null  int64
#  15  Year            10840 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# ...

# %%
df.describe().T
# Out:
#             count          mean           std     min     25%       50%  \
# Rating     9366.0  4.191757e+00  5.152189e-01     1.0     4.0       4.3
# Reviews   10840.0  4.441529e+05  2.927761e+06     0.0    38.0    2094.0
# Size       9145.0  2.150653e+04  2.259602e+04    10.0  4900.0   13000.0
# Installs  10840.0  1.546434e+07  8.502936e+07     0.0  1000.0  100000.0
# Price     10840.0  1.027368e+00  1.594970e+01     0.0     0.0       0.0
# Day       10840.0  1.560904e+01  9.561621e+00     1.0     6.0      16.0
# Month     10840.0  6.422325e+00  2.578388e+00     1.0     5.0       7.0
# Year      10840.0  2.017400e+03  1.100914e+00  2010.0  2017.0    2018.0
#
#                 75%           max
# Rating          4.5  5.000000e+00
# Reviews     54775.5  7.815831e+07
# Size        30000.0  1.000000e+05
# Installs  5000000.0  1.000000e+09
# Price           0.0  4.000000e+02
# Day            24.0  3.100000e+01
# Month           8.0  1.200000e+01
# Year         2018.0  2.018000e+03

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'Day', 'Month', 'Year'],
#       dtype='object')

# %%
df[df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10767                                             AAFP       MEDICAL     3.8
#
# ...

# %%
df[df.duplicated("App")]
# Out:
#                                       App       Category  Rating  Reviews  \
# 229          Quick PDF Scanner + OCR FREE       BUSINESS     4.2    80805
# 236                                   Box       BUSINESS     4.2   159872
# 239                    Google My Business       BUSINESS     4.4    70991
# 256                   ZOOM Cloud Meetings       BUSINESS     4.4    31614
# 261             join.me - Simple Meetings       BUSINESS     4.0     6989
# ...                                   ...            ...     ...      ...
# 10714                  FarmersOnly Dating         DATING     3.0     1145
# 10719  Firefox Focus: The privacy browser  COMMUNICATION     4.4    36981
# 10729                         FP Notebook        MEDICAL     4.5      410
# 10752      Slickdeals: Coupons & Shopping       SHOPPING     4.5    33599
# 10767                                AAFP        MEDICAL     3.8       63
#
#           Size  Installs  Type  Price Content Rating         Genres  \
# ...

# %%
df=df.drop_duplicates(subset=["App"],keep='first')

# %%
df.shape
# Out:
# (9659, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9659 entries, 0 to 10839
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9659 non-null   object
#  1   Category        9659 non-null   object
#  2   Rating          8196 non-null   float64
#  3   Reviews         9659 non-null   int64
#  4   Size            8432 non-null   float64
#  5   Installs        9659 non-null   int64
#  6   Type            9658 non-null   object
#  7   Price           9659 non-null   float64
#  8   Content Rating  9659 non-null   object
#  9   Genres          9659 non-null   object
#  10  Last Updated    9659 non-null   object
#  11  Current Ver     9651 non-null   object
#  12  Android Ver     8667 non-null   object
#  13  Day             9659 non-null   int64
#  14  Month           9659 non-null   int64
#  15  Year            9659 non-null   int64
# dtypes: float64(3), int64(5), object(8)
# memory usage: 1.3+ MB

# %%
numeric_features=[feature for feature in df.columns if df[feature].dtype !='O']

# %%
numeric_features
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'Day', 'Month', 'Year']

# %%
categorical_features=[feature for feature in df.columns if df[feature].dtype=='O']

# %%
categorical_features
# Out:
# ['App',
#  'Category',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
df["Type"].value_counts()
# Out:
# Type
# Free    8902
# Paid     756
# Name: count, dtype: int64

# %%
df["Type"].value_counts(normalize=True)
# Out:
# Type
# Free    0.921723
# Paid    0.078277
# Name: proportion, dtype: float64

# %%
df["Type"].value_counts(normalize=True)*100
# Out:
# Type
# Free    92.172292
# Paid     7.827708
# Name: proportion, dtype: float64

# %%
for col in categorical_features:
    print(f"{col}:{df[col].value_counts(normalize=True)*100}")
    print("==================================================")
# Out:
# App:App
# Photo Editor & Candy Camera & Grid & ScrapBook    0.010353
# Tic Tac CK                                        0.010353
# INFAMY RO                                         0.010353
# CK Call NEW                                       0.010353
# Ck Coif                                           0.010353
#                                                     ...
# Bike Race Free - Top Motorcycle Racing Games      0.010353
# Dance School Stories - Dance Dreams Come True     0.010353
# 3D Bowling                                        0.010353
# Mind Games Pro                                    0.010353
# iHoroscope - 2018 Daily Horoscope & Astrology     0.010353
# Name: proportion, Length: 9659, dtype: float64
# ...
# Category:Category
# FAMILY                 18.966767
# GAME                    9.928564
# TOOLS                   8.561963
# BUSINESS                4.348276
# MEDICAL                 4.089450
# PERSONALIZATION         3.892743
# PRODUCTIVITY            3.872036
# ...

# %%
sns.countplot(x=df["Type"])
# Out:
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %%
sns.countplot(x=df["Content Rating"])
# Out:
# <AxesSubplot:xlabel='Content Rating', ylabel='count'>

# %%
plt.figure(figsize=(20,15))
plt.suptitle('Univariate Analysis of Categorical Features',fontsize=20,fontweight='bold',alpha=0.8,y=1)
category=["Type",'Content Rating']
for i in range(0,len(category)):
    plt.subplot(2,2,i+1)
    sns.countplot(x=df[category[i]],palette="Set2")
    plt.xlabel(category[i])
    plt.xticks(rotation=45)
    plt.tight_layout()

# %%
numeric_features
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'Day', 'Month', 'Year']

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1463
# Reviews              0
# Size              1227
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver        992
# Day                  0
# Month                0
# Year                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9659 entries, 0 to 10839
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9659 non-null   object
#  1   Category        9659 non-null   object
#  2   Rating          8196 non-null   float64
#  3   Reviews         9659 non-null   int64
#  4   Size            8432 non-null   float64
#  5   Installs        9659 non-null   int64
#  6   Type            9658 non-null   object
#  7   Price           9659 non-null   float64
#  8   Content Rating  9659 non-null   object
#  9   Genres          9659 non-null   object
#  10  Last Updated    9659 non-null   object
#  11  Current Ver     9651 non-null   object
#  12  Android Ver     8667 non-null   object
#  13  Day             9659 non-null   int64
#  14  Month           9659 non-null   int64
#  15  Year            9659 non-null   int64
# dtypes: float64(3), int64(5), object(8)
# memory usage: 1.3+ MB

# %%
plt.figure(figsize=(15,15))
plt.suptitle("Univaries feature of Numerical feature",fontsize=20, fontweight='bold',alpha=0.8,y=1)
for i in range(0,len(numeric_features)):
    plt.subplot(5,3,i+1)
    sns.kdeplot(x=df[numeric_features[i]],shade=True,color='r')
    plt.xlabel(numeric_features[i])
    plt.tight_layout()

# %%
plt.hist(df['Rating'])
plt.show()

# %%
#Q most popular category in the app
#Univariate analysis

df['Category'].value_counts().plot.pie(y=df['Category'],figsize=(15,15))
# Out:
# <AxesSubplot:ylabel='count'>

# %%
df['App'].value_counts().plot.pie(y=df['App'])
# Out:
# <AxesSubplot:ylabel='count'>

# %%
df['Category'].value_counts().plot.pie(y=df['Category'],figsize=(15,15),autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='count'>

# %%
df_cat=df["Category"].value_counts()[:10]

# %%
category=pd.DataFrame(df['Category'].value_counts())
category.rename(columns={'Category':'Count'},inplace=True)

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %% [markdown]
# BIvarient analysis

# %%
# WHICH CATEGORY HAVING LARGEST NUMBER OF INSTALLATION

df.groupby(['Category'])['Installs'].sum().sort_values()
# Out:
# Category
# EVENTS                    15973161
# BEAUTY                    27197050
# PARENTING                 31521110
# MEDICAL                   38193177
# COMICS                    44981150
# LIBRARIES_AND_DEMO        52995910
# AUTO_AND_VEHICLES         53130211
# HOUSE_AND_HOME            97212461
# ART_AND_DESIGN           114338100
# DATING                   140926107
# FOOD_AND_DRINK           211798751
# EDUCATION                352952000
# WEATHER                  361100520
# FINANCE                  455348734
# MAPS_AND_NAVIGATION      503281890
# LIFESTYLE                503823539
# BUSINESS                 697164865
# SPORTS                  1096474498
# HEALTH_AND_FITNESS      1144022512
# SHOPPING                1400348785
# PERSONALIZATION         1532494782
# BOOKS_AND_REFERENCE     1665969576
# ENTERTAINMENT           2113660000
# NEWS_AND_MAGAZINES      2369217760
# TRAVEL_AND_LOCAL        2894887146
# VIDEO_PLAYERS           3926902720
# ...

# %%
#IF WE NEED TO CONVERT THIS INTO DATA  FRAME
df_cat_installs=df.groupby(['Category'])['Installs'].sum().sort_values(ascending=False).reset_index()

# %%
df_cat_installs
# Out:
#                Category     Installs
# 0                  GAME  13878924415
# 1         COMMUNICATION  11038276251
# 2                 TOOLS   8001771915
# 3          PRODUCTIVITY   5793091369
# 4                SOCIAL   5487867902
# 5           PHOTOGRAPHY   4649147655
# 6                FAMILY   4427941505
# 7         VIDEO_PLAYERS   3926902720
# 8      TRAVEL_AND_LOCAL   2894887146
# 9    NEWS_AND_MAGAZINES   2369217760
# 10        ENTERTAINMENT   2113660000
# 11  BOOKS_AND_REFERENCE   1665969576
# 12      PERSONALIZATION   1532494782
# 13             SHOPPING   1400348785
# 14   HEALTH_AND_FITNESS   1144022512
# 15               SPORTS   1096474498
# 16             BUSINESS    697164865
# 17            LIFESTYLE    503823539
# 18  MAPS_AND_NAVIGATION    503281890
# 19              FINANCE    455348734
# 20              WEATHER    361100520
# 21            EDUCATION    352952000
# 22       FOOD_AND_DRINK    211798751
# 23               DATING    140926107
# ...

# %%
df2=df_cat_installs.head(10)

# %%
sns.barplot(x="Installs",y="Category",data=df2)
# Out:
# <AxesSubplot:xlabel='Installs', ylabel='Category'>

# %%
plt.figure(figsize=(14,10))
sns.set_context("talk")
sns.set_style("darkgrid")

ax=sns.barplot(x="Installs",y="Category",data=df2)
ax.set_xlabel("No of installation in Billions")
ax.set_ylabel(" ")
ax.set_title("Most popular category in playstore",size=20)
# Out:
# Text(0.5, 1.0, 'Most popular category in playstore')

# %% [markdown]
# # what are the top 5 most installed apps in each categoey

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
dfa=df.groupby(['Category','App'])['Installs'].sum().reset_index()

# %%
dfa=dfa.sort_values("Installs",ascending=False)

# %%
dfa[dfa.Category=='GAME'][:5]
# Out:
#      Category               App    Installs
# 4773     GAME    Subway Surfers  1000000000
# 4167     GAME  Candy Crush Saga   500000000
# 4628     GAME               Pou   500000000
# 4802     GAME      Temple Run 2   500000000
# 4580     GAME    My Talking Tom   500000000

# %%
dfa[dfa.Category=='PRODUCTIVITY'][:5]
# Out:
#           Category              App    Installs
# 7427  PRODUCTIVITY     Google Drive  1000000000
# 7472  PRODUCTIVITY   Microsoft Word   500000000
# 7425  PRODUCTIVITY  Google Calendar   500000000
# 7364  PRODUCTIVITY          Dropbox   500000000
# 7334  PRODUCTIVITY      Cloud Print   500000000

# %%
apps=["GAME","COMMUNICATION","PRODUCTIVITY","SOCIAL"]
sns.set_context("poster")
sns.set_style("darkgrid")
plt.figure(figsize=(40,30))
for i, app in enumerate(apps):
    df2=dfa[dfa.Category==app]
    df3=df2.head(5)
    plt.subplot(4,2,i+1)
    sns.barplot(data=df3,x="Installs",y="App")
    plt.xlabel("Installation in millions")
    plt.ylabel("")
    plt.title(app,size=20)
    
plt.tight_layout()
plt.subplots_adjust(hspace=.3)
plt.show()

# %% [markdown]
# How many apps are there on Google play store which get 5 Rating??

# %%
rating=df.groupby(['App'])['Rating'].sum().sort_values(ascending=False).reset_index()

# %%
rating
# Out:
#                                                    App  Rating
# 0                            Comunidad De Fe Minitries     5.0
# 1                                      Tablet Reminder     5.0
# 2                                Noticias FC Barcelona     5.0
# 3     Superheroes, Marvel, DC, Comics, TV, Movies News     5.0
# 4                    DC N COMPANY ENTERTAINMENT RADIO!     5.0
# ...                                                ...     ...
# 9654                              DK Childcare Centers     0.0
# 9655                         Pediatric Emergency Guide     0.0
# 9656                                     Pekalongan CJ     0.0
# 9657                        Penn State Health OnDemand     0.0
# 9658              "i DT" Fútbol. Todos Somos Técnicos.     0.0
#
# [9659 rows x 2 columns]

# %%
rating[rating.Rating==5.0]
# Out:
#                                                   App  Rating
# 0                           Comunidad De Fe Minitries     5.0
# 1                                     Tablet Reminder     5.0
# 2                               Noticias FC Barcelona     5.0
# 3    Superheroes, Marvel, DC, Comics, TV, Movies News     5.0
# 4                   DC N COMPANY ENTERTAINMENT RADIO!     5.0
# ..                                                ...     ...
# 266                     American Girls Mobile Numbers     5.0
# 267                                         daskal.eu     5.0
# 268                         Free coupons and vouchers     5.0
# 269                                      Bk Usha behn     5.0
# 270                           Asha Ek Hope - ALS/ MND     5.0
#
# [271 rows x 2 columns]

# %%
rating2 = df.groupby(["Category","Installs","App"])["Rating"].sum().sort_values(ascending=False).reset_index()

# %%
rating2
# Out:
#             Category  Installs  \
# 0             FAMILY      1000
# 1             DATING       100
# 2             FAMILY        10
# 3             DATING       500
# 4            MEDICAL         5
# ...              ...       ...
# 9654           TOOLS       100
# 9655           TOOLS       100
# 9656        BUSINESS       100
# 9657           TOOLS       100
# 9658  ART_AND_DESIGN         0
#
#                                                    App  Rating
# 0                          CS & IT Interview Questions     5.0
# 1                              Online Girls Chat Group     5.0
# 2                                        Chronolink DX     5.0
# 3                                Spine- The dating app     5.0
# 4                                    Clinic Doctor EHr     5.0
# ...                                                ...     ...
# 9654                                         CG Wizard     0.0
# 9655  CG 3D Model Viewer: view 3D models interactively     0.0
# ...

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'Day', 'Month', 'Year'],
#       dtype='object')

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(data=df,y="Category",x="Price")
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Category'>

# %% [markdown]
# # Which category  app user are reviewing the most

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
df.groupby(["Category","App"])["Reviews"].sum().sort_values(ascending=False).reset_index()
# Out:
#                  Category                                       App   Reviews
# 0                  SOCIAL                                  Facebook  78158306
# 1           COMMUNICATION                        WhatsApp Messenger  69119316
# 2                  SOCIAL                                 Instagram  66577313
# 3           COMMUNICATION  Messenger – Text and Video Chat for Free  56642847
# 4                    GAME                            Clash of Clans  44891723
# ...                   ...                                       ...       ...
# 9654            LIFESTYLE                                        DT         0
# 9655                TOOLS                             AQ SMS Notify         0
# 9656                TOOLS                               AQ wisdom +         0
# 9657  BOOKS_AND_REFERENCE                               Schlaumeier         0
# 9658              MEDICAL                    POCKET BOOK CT ABDOMEN         0
#
# [9659 rows x 3 columns]

# %%
df.groupby('Category').agg({"App":"sum","Reviews":"sum"})
#you can take any categorical variable in group by and in aggregate take any quantitative variable
# Out:
#                                                                    App  \
# Category
# ART_AND_DESIGN       Photo Editor & Candy Camera & Grid & ScrapBook...
# AUTO_AND_VEHICLES    Monster Truck Stunt 3D 2019Real Tractor Farmin...
# BEAUTY               Hush - Beauty for Everyoneipsy: Makeup, Beauty...
# BOOKS_AND_REFERENCE  Wattpad 📖 Free BooksE-Book Read - Read Book fo...
# BUSINESS             Visual Voicemail by MetroPCSIndeed Job SearchU...
# COMICS               LINE WEBTOON - Free ComicsManga Master - Best ...
# COMMUNICATION        Messenger – Text and Video Chat for FreeWhatsA...
# DATING               Moco+ - Chat, Meet PeopleCalculatorTruth or Da...
# EDUCATION            Duolingo: Learn Languages FreeTEDEnglish Commu...
# ENTERTAINMENT        NetflixComplete Spanish MoviesPluto TV - It’s ...
# EVENTS               All Events in CityTicketmaster Event TicketsRe...
# FAMILY               Jewels Crush- Match 3 PuzzleColoring & LearnMa...
# ...

# %%
df.groupby("Type").agg({"Installs":"sum"})
# Out:
#          Installs
# Type
# Free  75065572646
# Paid     57364881

# %%
fig,ax=plt.subplots(1,2,figsize=(20,7))
df.value_counts("Type").plot.pie(y="Type",startangle=90,explode=(0.2,0),title='Percentage oof the free app and paid app',legend=False,autopct="%.2f",ax=ax[0])
ax[0].set(ylabel="Type of Apps")
df.groupby("Type").agg({"Installs":sum}).plot.pie(y="Installs",startangle=90,explode=(0.2,0),title="Percentage of installs number for free and Paid App",legend=False,autopct="%.2f",ax=ax[1])
# Out:
# <AxesSubplot:title={'center':'Percentage of installs number for free and Paid App'}, ylabel='Installs'>

# %%
plt.figure(figsize=(15,15))
sns.boxplot(x="Installs",y="Rating",data=df)
# Out:
# <AxesSubplot:xlabel='Installs', ylabel='Rating'>

# %%
plt.figure(figsize=(15,15))
sns.boxplot(x="Installs",y="Rating",data=df)
plt.xticks(size=15,rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.boxplot(x="Category",y="Rating",data=df)
plt.xticks(size=15,rotation=90)
plt.show()

# %% [markdown]
# # Which categor app in of larger size

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
large=df.groupby(["Category"])["Size"].sum().sort_values(ascending=False).reset_index()

# %%
plt.figure(figsize=(15,15))
sns.barplot(x='Category',y='Size',data=df)
plt.xticks(size=20,rotation=90)
plt.show()

# %%
plt.subplots(figsize=(20,10))
freq=pd.Series()
freq=df["Year"].value_counts()
freq.plot()
plt.xlabel("Dates")
plt.ylabel("Number of updates")
plt.title("Time series plot of Last Updates")
# Out:
# Text(0.5, 1.0, 'Time series plot of Last Updates')

# %%
plt.figure(figsize=(15,8))
sns.countplot(x="Rating",data=df,palette="Set1_r")
plt.xticks(rotation=90)
plt.title("Countplot for rating")
plt.show()
